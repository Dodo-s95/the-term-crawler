# %%
import spacy
import csv
import pandas as pd

from spacy.lang.char_classes import ALPHA, ALPHA_LOWER, ALPHA_UPPER
from spacy.lang.char_classes import CONCAT_QUOTES, LIST_ELLIPSES, LIST_ICONS
from spacy.util import compile_infix_regex

# %%
nlp = spacy.load("en_core_web_sm")

# modify tokenizer infix patterns for avoiding hyphenated words being split (several terms are hyphenated)

infixes = (
    LIST_ELLIPSES
    + LIST_ICONS
    + [
        r"(?<=[0-9])[+\-\*^](?=[0-9-])",
        r"(?<=[{al}{q}])\.(?=[{au}{q}])".format(
            al=ALPHA_LOWER, au=ALPHA_UPPER, q=CONCAT_QUOTES
        ),
        r"(?<=[{a}]),(?=[{a}])".format(a=ALPHA),
        r"(?<=[{a}0-9])[:<>=/](?=[{a}])".format(a=ALPHA),
    ]
)

infix_re = compile_infix_regex(infixes)
nlp.tokenizer.infix_finditer = infix_re.finditer

# %%
def read_tsv(link):
    with open(link, "r", encoding="utf-8") as tsvfile:
        reader = csv.reader(tsvfile, delimiter="\t")
        next(reader) # skip header
        return {row[2].split(": ")[1] for row in reader}

terms_lexicon = read_tsv("../swimming-terms.tsv") 
# list of extracted terms

# %%
terms_lexicon
# Out:
# {'physique',
#  'bachman',
#  'pb improvement',
#  'term of volume and intensity',
#  'young',
#  'firma',
#  'meter swimming',
#  'speed swimming',
#  'algorithm',
#  'root-\xad‐mean-\xad‐square',
#  'potential pb',
#  'lung',
#  'share',
#  'catch point',
#  'beginning of backstroker',
#  'biomechanists',
#  'breaststroke swimming',
#  'center of mass velocity',
#  'implication of current fina',
#  'ernest',
#  'regularity',
#  'combination of right hand',
#  'type of stroke',
#  'model lsb302',
#  'mental fortitude',
#  'repeated sprint training',
#  'negative factor',
#  'huge increase',
#  'palmer',
#  'post-\xad‐test',
#  'factor',
#  'total number of stroke',
#  'swimmer arm',
#  'line with body',
#  'morphological change',
#  'bicycle short-\xad‐sprint training',
#  'central training effect',
#  'production of electrode',
#  'ergogenic aid',
#  'additional oxygen',
#  'scapular stabilization',
#  'large effect',
#  'dave tanner1',
#  'result of propulsion',
#  'average',
#  'relevance of current datum',
#  'joint torques',
#  'muscle imbalance',
#  'loftice',
#  'olympic competition',
#  'repeat speed',
#  'nogue',
#  'high training volume',
#  'effect of altitude training',
#  'methacholine challenge',
#  'trindade',
#  'openly',
#  'kellmann',
#  'magnitude of improvement of swimmer',
#  'decade',
#  'drag lift figure',
#  'complex',
#  'attainment of strong position',
#  'usa 2rehabilitation',
#  'additional detail',
#  'drake1',
#  'american journal of sport medicine',
#  'bilateral propulsive force difference',
#  'exhaustion',
#  'side and loss of strength',
#  'starkes',
#  'hurdle',
#  'hand entry',
#  'thirdly',
#  'flat board',
#  'lazy meadow lane prescott',
#  'jenkins',
#  'underwater undulation',
#  'sallis',
#  'fina rule',
#  'approach',
#  'knee extension',
#  'electronic touch pad',
#  'mental and emotional attribute',
#  'incidentally',
#  'uncomfortable',
#  'alison alcock2',
#  'push-\xad‐off',
#  'front crawl arm stroke',
#  'challenging experience',
#  'clinical shoulder symptom',
#  '321-\xad‐',
#  'myoglobin',
#  'non-\xad‐acclimatized swimmer',
#  'coyle',
#  'photo of zubero',
#  'fitts',
#  'present result',
#  'fazarale',
#  'support',
#  'practice of blood lactate testing',
#  'small amount of datum',
#  'dry land program',
#  'hendrikson',
#  'throwing',
#  'muller',
#  'orthopaedics and sport medicine',
#  'health science',
#  'remainder of week',
#  'high volume of freestyle swimming',
#  'preventive measure',
#  'start of propulsive phase',
#  'two-\xad‐peak style',
#  'red portion of stroke pattern',
#  'specific overuse injury',
#  'electromyography',
#  'af stopping',
#  'ullevål stadion',
#  'replicators',
#  'established',
#  'ship',
#  'straight lumbar alignment',
#  'jones',
#  'preliminary heat',
#  'propulsive final upsweep',
#  'freeman',
#  'investigation',
#  'hypothesis',
#  'direct effect',
#  'relative difference',
#  'time but haphazard attempt',
#  'strained',
#  'workout',
#  'personal good swim time',
#  'conventional training plan',
#  'menstrual cycle',
#  'group training',
#  'major asymmetry',
#  'overuse injury symptom',
#  'traditional periodization program',
#  'self-\xad‐talk',
#  'quality of physical training',
#  'chi-\xad‐square',
#  'freriks',
#  'present day',
#  'phelps',
#  'in-\xad‐water preventive measure',
#  'swim-\xad‐volume-\xad‐induced supraspinatus tendinopathy',
#  'jesse vassallo',
#  'current',
#  'deeply',
#  'optimal joint lever system',
#  'sauers',
#  'personalized',
#  'nutrition & exercise science',
#  'type of fiber',
#  'athletic environment',
#  'transporter',
#  'rod havriluk swimming technology research',
#  'parker',
#  'interdependent relationship',
#  'turn',
#  'low limb injury',
#  'high-\xad‐intensity',
#  'misalignment',
#  'kuah',
#  'shoulder movement',
#  'kyphosis of spine',
#  'order',
#  'estimate of progression and variability',
#  'basically',
#  'training load group',
#  'worth',
#  'pain with shoulder abduction',
#  'zubero',
#  'constantly',
#  'timely',
#  'vaguely',
#  'incorrect hand entry angle',
#  'heat loss',
#  'state university po box',
#  'training load',
#  'effective training program',
#  'significant two-way olympiad',
#  'sensory',
#  'jonesboro',
#  'targeted intervention',
#  'recuperation',
#  'progressive decrease',
#  'website designer',
#  'energy contribution',
#  'quadrennial cycle',
#  'muscle weakness',
#  'hebbal',
#  'intrinsic layer',
#  'session of sprint interval training',
#  'competitive front-\xad‐crawl swimmer',
#  'realistic opportunity',
#  'upper and low limb',
#  'aspect of swim training',
#  'abascal',
#  'day-\xad‐',
#  'wake',
#  'duration',
#  'murrell',
#  'olympic team',
#  'preferable',
#  'daily activity',
#  'short sprint',
#  'informed consent',
#  'structural asymmetry',
#  'lees',
#  'overabundance of food',
#  'sangoi',
#  'current sample',
#  'low-\xad‐intensity swimming',
#  'oceanic and atmospheric administration',
#  'journal of experimental biology,115',
#  'result of improper technique',
#  'water',
#  'red arrow',
#  'kuehl',
#  'cold-\xad‐water swimming',
#  'battery of test',
#  'inflammation and release of enzyme',
#  'ecgs',
#  'age group swimmer',
#  'intent',
#  'conventional wisdom',
#  'mild discomfort',
#  'elite-level female swimmer',
#  'qualification of usa swimming coach',
#  'valuable electrolyte',
#  'shoulder laxity',
#  'high-\xad‐volume training',
#  'marque',
#  'true',
#  'elite and novice swimmer',
#  'falk',
#  'cb walter',
#  'spearman-\xad‐brown rtt',
#  'decrease',
#  'large muscle',
#  'circular',
#  'gratziou',
#  'devulapalli cs',
#  'innumerable',
#  'auditory signal',
#  'body composition parameter',
#  'myocyte activity',
#  'dotted yellow arrow',
#  'popular swimming stroke',
#  'physical examination',
#  'scenario with small number',
#  'dudley',
#  'responsiveness',
#  'perception of performance climate',
#  'bilateral arm power imbalance',
#  'author',
#  'team be fast',
#  'instructor',
#  'baby',
#  'level mini',
#  'asymmetry and movement asymmetry',
#  'primary focus of athlete',
#  '%mvc',
#  'aerobic and anaerobic threshold velocity',
#  'hip roll change',
#  'year-old',
#  'short-\xad‐send',
#  'website',
#  'benefit and potential drawback',
#  'stracener',
#  'database',
#  'decidedly',
#  'high resistance',
#  'wilcoxon',
#  'great caution',
#  'perpendicular',
#  '4-\xad‐week',
#  'direct measurement of force',
#  'respective training',
#  'fat percentage',
#  'equipment',
#  'late maturers',
#  'inadequate recovery',
#  'part of cycle',
#  'champaign',
#  'jeukendrup',
#  'action be primary',
#  'gradual',
#  'swimmer ability',
#  'end of leg downbeat',
#  'reflex apnea',
#  'physiology school level',
#  'seiler',
#  'shibata',
#  'lane of pool',
#  'technique drill',
#  'chair',
#  'high-\xad‐intensity repeat',
#  'mct4',
#  'sport medicine',
#  'spinal asymmetry',
#  'variant number',
#  'raha',
#  'vasoconstriction',
#  'block handgrip actualization',
#  'complication of neuromuscular disease',
#  'non-\xad‐breathing cycle',
#  'young competitive distance runner',
#  'single arm amputee swimmer',
#  'public',
#  'bottom left photo',
#  'sport nutr exerc metab',
#  'backward and downward direction',
#  'thirty-nine year',
#  'prescribed activity',
#  'dolphin club',
#  'sharmon robinson1',
#  'swim belt',
#  'intra',
#  'sum of reading',
#  'relay competition result',
#  'physical medicine',
#  'straight line pull johnson soh',
#  'path close',
#  'custom fitted swimsuit',
#  'dolphin-\xad‐kicking',
#  'procedure',
#  'washington',
#  'altitude training strategy',
#  'high-\xad‐intensive interval training',
#  'physiology nutrition metabolism',
#  'randomly',
#  'inability',
#  'salo',
#  'effect of handedness',
#  'acta',
#  'human movement',
#  'mileage',
#  'maximum sprint speed',
#  'fame',
#  'health care provider',
#  'superiority',
#  'fink',
#  'regular diet',
#  'mechanism of oxygen delivery',
#  'conjectured—although',
#  'individual measure',
#  'early season',
#  'association',
#  'bipolar',
#  'field-\xad‐testing',
#  'quantitative datum',
#  'anatomical movement',
#  'asthmatic',
#  'knee',
#  'advice of healthcare provider',
#  'upbeat and downbeat of kick',
#  'guillet-\xad‐descas',
#  'prolonged rest',
#  'normal population',
#  'flume',
#  'noticeable fall-\xad‐off',
#  'vo2 peak',
#  'skinfold measure',
#  'schilling',
#  'hand paddle',
#  'day-\xad‐of-\xad‐competition strategy',
#  'key role',
#  'front',
#  'stroke count',
#  'talent development',
#  'nation',
#  'powerfully',
#  'lack of progress',
#  'roper',
#  'high average hand force',
#  'propensity',
#  'scope of work',
#  'physiological perspective',
#  'early catch with elbow',
#  'maturational event',
#  'emmanuel gourmelin valérie schwob laboratoire',
#  'detail',
#  'importance',
#  'bilateral symmetry',
#  'swim bench exercise',
#  'off-\xad‐response',
#  'artificially',
#  'future training decision',
#  'kjoc score',
#  'department of coaching and sport psychology',
#  'izumi tabata',
#  'future injury prevention education',
#  'repeated measure',
#  'wuc-\xad‐265',
#  'national-level female swim',
#  'unilaterally',
#  'two-\xad‐peak arm stroke',
#  'frequency datum',
#  'position statement',
#  'fall',
#  'firm conclusion',
#  'swimmer laterality',
#  'strain',
#  'primary focus',
#  'impingement',
#  'fine motor skill',
#  'schroder',
#  'top athlete',
#  'interactive coordination',
#  'focus be negative',
#  'competitive swimming relay performance result',
#  'kinetics publisher',
#  'influence',
#  'beta-\xad‐2 receptor',
#  'pb success rate',
#  'great utilization',
#  'alignment and trunk muscle',
#  'sprint-\xad‐assisted training',
#  'pre-pubertal',
#  'vertical gray line',
#  '30-\xad‐minute',
#  'entry and incorrect hand',
#  'high preference',
#  'saint-\xad‐étienne',
#  'skill development',
#  'apparent',
#  'similar pattern',
#  'viscous',
#  'introduction competitive swimmer',
#  'high',
#  'commonality',
#  'battery of kinematic variable',
#  'sub-elite',
#  'symposium',
#  'undue stress',
#  'endurance-trained',
#  'journal of sport science',
#  'performance testing',
#  'great degree of resistance',
#  'recommendation be consistent',
#  'noreen ee',
#  'female backstroker',
#  'daly',
#  'sprint time',
#  'subsequently',
#  'back face',
#  'streamlining',
#  'measure be large',
#  'focus',
#  'model of periodization',
#  'baseline asca training',
#  'perspective',
#  'speed variable',
#  'point of body',
#  'graciously',
#  'shoulder be noticeable',
#  'account',
#  'acquisition',
#  'mid-\xad‐way',
#  'development of technique',
#  'non-\xad‐takeoff low limb',
#  'interactive webinars',
#  'duplischeva',
#  'maturation',
#  'main question',
#  'peak rms',
#  'stress-\xad‐recovery state',
#  'successfully',
#  'combination of arm and leg',
#  'stager3',
#  'speed',
#  'upper arm',
#  'sentence',
#  'central concern',
#  'importance of psychological skill',
#  'pull buoy',
#  'kind of training',
#  'accuracy of recall',
#  'musculoskeletal complication',
#  'arm amputee paralympic swimmer',
#  '1950s',
#  'miyachi',
#  'natural advantage',
#  'motivation',
#  'surface of water',
#  'result of research',
#  'backward force',
#  'study design',
#  'vo2max velocity',
#  'instance',
#  'perfectionism factor',
#  'pre-\xad‐ intervention time trial',
#  'parlebas',
#  'sea level swimming training',
#  'prioux',
#  'pegelow',
#  'bullen',
#  'rowing',
#  'adolescence',
#  'aerobically',
#  'puntscahrt',
#  'important component',
#  'additional physiological adaptation',
#  'broadway san antonio',
#  'compromise',
#  'effect of ss warm-\xad‐up',
#  'michael',
#  'major contributor',
#  'trudgen',
#  'result of change',
#  'result of experiment',
#  'parental pressure',
#  'specific recommendation',
#  'cluster',
#  'strength deficit',
#  'terrestrial mammal',
#  'passive range of motion',
#  'heavy training force',
#  'cortex',
#  'brown',
#  'peak forward velocity',
#  'injured shoulder',
#  'overtraining',
#  'arm outward',
#  'achievement goal',
#  'long-\xad‐term goal',
#  'graphic representation of manner',
#  'pereira',
#  'drag-\xad‐based',
#  'intense effort',
#  'boat paddle',
#  'water action',
#  'contractile speed',
#  'head',
#  'consistency',
#  'anth',
#  'primary investigator',
#  'sub-\xad‐threshold training',
#  'optimal performance',
#  'lahart',
#  'variable be indicative',
#  'prentice-\xad‐hall',
#  'amenorrhea',
#  'menzies',
#  'placing',
#  'result of correlation analysis',
#  'taurine',
#  'reasonable',
#  'warm-\xad‐up protocol',
#  'adenosine monophosphate',
#  'robergs',
#  'febbraio',
#  'critic',
#  'purpose of review',
#  'considerable speculation with regard',
#  '5-point',
#  'high-\xad‐resistance',
#  'master athlete',
#  'upper and low limb bone',
#  'slow twitch counterpart',
#  'safely',
#  'unwittingly',
#  'underwater arm stroke',
#  'optimal result',
#  'lormes',
#  'aerobic training effect',
#  'personal',
#  'aerobic metabolic process',
#  'distribution model',
#  'olympic',
#  'overarm',
#  'head lift',
#  'retirement',
#  'national federation of state',
#  'posture',
#  'home',
#  'alignment of large shoulder',
#  'zouhal',
#  'obvious importance',
#  'kubo',
#  'definition of thoracic kyphosis',
#  't-\xad‐test',
#  'thessaloniki',
#  'youth sport',
#  'evaluation of athlete',
#  'symmetry index',
#  'african-american',
#  'struggle',
#  'training and racing strategy',
#  'distance',
#  'limb size',
#  'binevsky',
#  'normal',
#  'intense hyperventilation',
#  'slow twitch muscle fiber',
#  'psychological mechanism psychological skill',
#  'option',
#  'aerobic training zone',
#  'indianapolis',
#  'dexa',
#  'duration of phase of stroke',
#  'viscor',
#  'mason',
#  'lane',
#  'insweep',
#  'berthoin',
#  'rich',
#  'physiological change',
#  'intuitive',
#  'edwards',
#  'supervision',
#  'psychoneuroendocrinology',
#  'recovery and body roll',
#  'american college of sport medicine',
#  'experimental effect',
#  'variation of volume',
#  'smits',
#  'putman',
#  'jacobs',
#  'slender',
#  'taper',
#  'internally',
#  'main objective',
#  'body weight',
#  'squad',
#  'thanksgiving break',
#  'temporal characteristic of activation',
#  'grain',
#  'preferential',
#  'understanding of swimmer',
#  'ilegami',
#  'case anthropometric measure',
#  'length of lever arm',
#  'pink',
#  'middle season',
#  'end of tenth rib',
#  'familiar',
#  'birzinyte',
#  'actin-\xad‐ myosin',
#  'respiratory',
#  'athletic experience',
#  'izquierdo',
#  'tight',
#  'swimmer be unable',
#  'bradshaw',
#  'body position',
#  'parameter of body composition',
#  'john moffet',
#  'fitness',
#  'adduction',
#  'reason',
#  'role',
#  'optimal athletic performance',
#  'short relay exchange',
#  'polar bear challenge event',
#  'follow-\xad‐up and shoulder rehabilitation',
#  'callaway',
#  'forward speed',
#  'strong evidence',
#  'maintenance of muscle balance',
#  'interaction',
#  'step',
#  'monthly testing',
#  'inbody',
#  'dynamical asymmetry',
#  'nielens',
#  'negatively',
#  'clear',
#  'insweeping',
#  'independent sample t test',
#  'peak',
#  'arm pull',
#  'long distance event',
#  'influence of lateral preference',
#  'genetic',
#  'whistle',
#  'low altitude',
#  'seasonal hand force variation',
#  'blanton',
#  'current status with respect',
#  'increase',
#  'pre-\xad‐',
#  'rate with noticeable decrease',
#  'pankey',
#  'vervoorn',
#  'ymca',
#  'unaffected',
#  'delaplace',
#  'previous finding',
#  'crowd',
#  'european journal of paediatrics',
#  'aimlessly',
#  'table',
#  'elite backstroke',
#  'close',
#  'fatigue be normal',
#  'gently',
#  'clinical orthopaedic related research',
#  '800-m',
#  'team relay exchange time',
#  'external load',
#  'parallel',
#  'mild prolonged pain',
#  'specific problem',
#  'consistently',
#  'performer',
#  'time of competition',
#  'conclusion',
#  'fat-\xad‐free mass',
#  'physiology of sport and exercise',
#  'body fat',
#  'integral',
#  'non-\xad‐exercising age',
#  'total stroke',
#  'poor stroke technique',
#  'body segment',
#  'ferrari bravo',
#  'analysis of age',
#  'standardized time',
#  'in-\xad‐water start',
#  'overtraining syndrome',
#  'major type of muscle fiber',
#  'advantageous',
#  'functionality',
#  'near-\xad‐ maximum speed',
#  'inefficient',
#  'relative gain',
#  'place finisher',
#  'caty',
#  'matthews',
#  'enlargement',
#  'ego-\xad‐involved',
#  'olympic swimmer',
#  'lactate metabolism',
#  'conductive tissue',
#  'conjecture',
#  'region',
#  '50th percentile',
#  'severely',
#  'elbow',
#  'facet of training process',
#  'preferred hand',
#  'interested',
#  'speculative',
#  'amount of muscle activity',
#  'science',
#  'blood lactate',
#  'sport med phys fitness',
#  'unilateral breather',
#  'birthday',
#  'gold medalist',
#  'reality',
#  'race',
#  'cage',
#  'seasonal',
#  'existence of ftb fiber',
#  'special attention',
#  'opposite',
#  'specific task',
#  'martin zubero',
#  'stroke frequency',
#  'zigzag movement of hand',
#  'alves',
#  'ball',
#  '30-\xad‐second',
#  'lea loveless maurer',
#  'habituation',
#  'cure',
#  'paediatrics',
#  'performance test',
#  'logically',
#  'gian!mario!migliaccioa,b,1!,!andrea!di!nino!c,!francesco!avaldi!d,!alberto!bazzu!c,e',
#  'concern',
#  'stroke rate',
#  'remarkable',
#  'golub rm',
#  'overuse shoulder injury',
#  'online training',
#  'strengthened',
#  'upsweep or inward scull',
#  'posture and body orientation',
#  'factor factor',
#  'erect',
#  'lifespan of competitive swimmer',
#  'gender-\xad‐independent',
#  'hip joint',
#  'reliability',
#  'high resting oxygen consumption',
#  'anaerobic energy system capacity',
#  'reverse periodization',
#  'signal change with fatigue',
#  'training and assessment protocol',
#  'clanton',
#  'sims',
#  'capillary',
#  'netherlands',
#  'presence of scoliosis',
#  'critical speed',
#  'speed of breastroke swimming',
#  'insufficient',
#  'ingeniousness',
#  'baseline educational requirement',
#  'recovery stress',
#  'journal',
#  'small influence',
#  'adherence bandage',
#  'ordinarily',
#  'swimmer with successful performance',
#  'incidence of af',
#  'sample',
#  'pressure and segmental stability',
#  'back',
#  'aerobic period of volume',
#  'houghton-\xad‐mifflin',
#  'well-\xad‐timed body roll',
#  'albright',
#  'fiber be large',
#  'positive reinforcement',
#  'muscle performance',
#  'decrease muscle soreness',
#  'center of rotation',
#  'result be important',
#  'suer',
#  'rate of aerobic metabolism',
#  'preferentially',
#  'back of paddle',
#  'krueger',
#  'registered member',
#  'unexpectedly',
#  'hunter',
#  'shoeoe',
#  'nutrition neuromuscular research laboratory',
#  'sport psychology po box',
#  'peripheral adaptation',
#  'statistic',
#  'significant and positive impact',
#  'left hand photo',
#  'repetitive motion',
#  'literature',
#  'desire',
#  'muscle of deltoid and supraspinatus',
#  'glide factor',
#  'performance deficit',
#  'uneven development',
#  'study finding',
#  'preceding upsweep',
#  'extraordinary',
#  'mastery climate',
#  'indian or alaskan native',
#  'barbosa',
#  'luc collard emmanuel gourmelin valérie',
#  '50-\xad‐meter sprint',
#  'monnier - benoit',
#  'full time',
#  'propulsive force',
#  'pubmedcrossref',
#  'zone',
#  'clinically relevant information',
#  'criterion of success',
#  'length',
#  'water with internal rotation',
#  'long repeat distance',
#  'gabbe',
#  'female shape',
#  'elevated rate',
#  'long-\xad‐term multicenter',
#  'mackenzie',
#  'food',
#  'competitive swimmer',
#  'performance datum',
#  'relative contribution of strength',
#  'dominant arm',
#  'function of olympiad and sex',
#  'numerous external factor',
#  'rouboa ai',
#  'hydrodynamic drag',
#  'cumulative mile',
#  'fatigue',
#  'chronotropic',
#  'reed',
#  'barnett',
#  'ss-\xad‐',
#  'lanfranconi',
#  'lesson',
#  'resumption',
#  'threshold training',
#  'dietary intake',
#  'visual and graphic datum',
#  'damaging',
#  'janson',
#  'implication',
#  'goforth hw',
#  'aware',
#  'soccer',
#  'zealand',
#  '1917m',
#  '15-year-old',
#  'maximal oxygen uptake',
#  'recovery process',
#  'pre-\xad‐event',
#  'deficient',
#  'contour',
#  'club member',
#  'meyers',
#  'cold water',
#  'aspect',
#  'video of olympic champion',
#  'end-\xad‐ diastolic volume',
#  'monofin',
#  'ionotropic',
#  'reflex',
#  'breaststroke arm stroke',
#  'int j sport nutr exerc',
#  'effective coaching',
#  'kiputh',
#  'barale',
#  'recovery-schoolwork nexus',
#  'escudero',
#  'determination',
#  'frost ro',
#  'root',
#  'odontocete cetacean',
#  'role of muscle fiber structure',
#  'situational motivation scale',
#  'group of endurance',
#  'sleep',
#  'lung volume',
#  'tract of competitor',
#  'shape of human swimmer',
#  'calculation',
#  'threshold speed',
#  'anaerobic threshold',
#  'swimming-\xad‐based',
#  'structural damage',
#  'limitation',
#  'onset of hypothermia',
#  'software',
#  'end of summer season',
#  'john wiley',
#  'satisfaction',
#  'structure of skeleton',
#  'gaitanos',
#  'convinced',
#  'result of tethered swimming',
#  '300m swim',
#  'young adolescent swimmer',
#  'group',
#  'sierra wagner1',
#  'force with line of action',
#  'lewis',
#  'nature of practice and conditioning session',
#  'diastolic volume',
#  'marginal',
#  'base line of acromion',
#  'type of shoulder pain',
#  'lower-performers',
#  'effect of pressure drag',
#  'lack',
#  'frequency content of emg',
#  'gabriel',
#  'dolphin-\xad‐kick',
#  'active and passive recovery',
#  'postural measurement',
#  'sidaway',
#  'standardized team relay exchange time',
#  'lift vector',
#  'influence of training',
#  'capacity and lactate removal',
#  'individual sport',
#  'ubiquinone',
#  'munthe-kaas',
#  'anaerobic training zone',
#  'mandatory training',
#  '275-\xad‐',
#  'out-\xad‐sweep',
#  '400m freestyle relay',
#  'propulsive sweep',
#  'flexor of elderly male',
#  'joint lever system',
#  'type of muscle fiber',
#  'excessive shoulder revolution',
#  'journal of applied sport',
#  'siders university',
#  'zuleger',
#  'synergistically',
#  'good stroke mechanic',
#  'additional',
#  'early vertical forearm',
#  'hawkins',
#  'taper period',
#  'movement pattern',
#  'negative effect',
#  'injury be skeletal',
#  'high-\xad‐level',
#  'orange',
#  'texas state university',
#  ...}

# %%
# open 1 document, spacy it
with open("../corpus_txt/manuscript-maglischo-vol22.txt") as f: # corpus here
    doc = f.readlines()[0]
    doc = nlp(doc)

# %%
doc[0].lemma_
# Out:
# 'Swimming'

# %%
df = pd.DataFrame([item for sub in [[tok.text for tok in s]+["<eos>"] for s in doc.sents] for item in sub], columns=["token"])

df["lemma"] = [item for sub in [[token.lemma_.lower() if token.lemma_ != '-PRON-' else token.lower_ for token in s]+["<eos>"] for s in doc.sents] for item in sub]

# %%
df
# Out:
#          token     lemma
# 0     Swimming  swimming
# 1     Research  research
# 2            ,         ,
# 3          Vol       vol
# 4            .         .
# ...        ...       ...
# 9869  Swimming  swimming
# 9870         .         .
# 9871     <eos>     <eos>
# 9872        23        23
# 9873     <eos>     <eos>
#
# [9874 rows x 2 columns]

# %%
# populate 3rd column with "O" tags
df["tag"] = ["O"]*len(df)

# %%
max_term_len = max([len(x.split(" ")) for x in terms_lexicon])
print(max_term_len)
# Out:
# 6

# %% [markdown]
# # Attempts

# %% [markdown]
# ## 2 df n grams

# %%
# Creating a new df which contains the terms ngrams (n from 1 to 6)
# And the index of the first word of this ngram in the original df

ngram_df_entries = []

for i in range(1,max_term_len+1):
    for j in range(len(df)):
        if j+i > len(df):
            pass
        n_gram = ' '.join(df.iloc[j: j+i]["lemma"])
        if n_gram in terms_lexicon:
            ngram_df_entries.append([j, n_gram, i])

# %%
ngram_df = pd.DataFrame(columns=["starting_index", "ngram", "ngram_len"], data=ngram_df_entries)

# %%
ngram_df
# Out:
#       starting_index                               ngram  ngram_len
# 0                  0                            swimming          1
# 1                 14                                time          1
# 2                 21                            swimming          1
# 3                 22                          backstroke          1
# 4                 25                              ernest          1
# ...              ...                                 ...        ...
# 3180            2958         middle and right hand photo          5
# 3181            7438           period of trial and error          5
# 3182            7901     short and long backstroke event          5
# 3183            7919  male and female backstroke swimmer          5
# 3184            8917   significant loss of stroke length          5
#
# [3185 rows x 3 columns]

# %%
# Filtering duplicates (keeping the biggest ngrams)
ngram_df["is_duplicate"] = ngram_df.duplicated(subset="starting_index", keep='last')

# %%
ngram_df = ngram_df.query('is_duplicate == False')

# %%
for index, row in ngram_df.iterrows():
    #breakpoint()
    if row.ngram_len == 1:
        df.iloc[row.starting_index].tag = "I"
    else:
        for i in range(row.ngram_len):
            if i==0:
                tag = "B"
            else:
                tag = "I"
            df.iloc[row.starting_index+i].tag = tag

# %% [markdown]
# ## exploration

# %%
df.tag.value_counts()
# Out:
# O    6981
# I    2295
# B     598
# Name: tag, dtype: int64

# %%
df.query('tag=="B"')
# Out:
#          token     lemma tag
# 0     Swimming  swimming   B
# 29        Lazy      lazy   B
# 49        best      good   B
# 65      unique    unique   B
# 90      unique    unique   B
# ...        ...       ...  ..
# 9790    stroke    stroke   B
# 9798     elite     elite   B
# 9834     Human     human   B
# 9852    Online    online   B
# 9868       USA       usa   B
#
# [598 rows x 3 columns]

# %%
"swimming" in terms_lexicon
# Out:
# True

# %%
df.to_csv("dataset.txt", sep=" ",header=False, index=False, columns=["token", "tag"])

# %%
df
# Out:
#          token     lemma tag
# 0     Swimming  swimming   B
# 1     Research  research   I
# 2            ,         ,   O
# 3          Vol       vol   O
# 4            .         .   O
# ...        ...       ...  ..
# 9869  Swimming  swimming   I
# 9870         .         .   O
# 9871     <eos>     <eos>   O
# 9872        23        23   O
# 9873     <eos>     <eos>   O
#
# [9874 rows x 3 columns]
